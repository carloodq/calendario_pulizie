# %%
import pandas as pd
from datetime import datetime
df = pd.read_csv("turni.csv")

# %%
df.head()
# Out:
#   collaboratore    reparto                periodo       turno
# 0      RIGGIERO        228  15/09/2025-21/09/2025     mattina
# 1      DARIMINI        228  15/09/2025-21/09/2025  pomeriggio
# 2        GIUSTI        228  15/09/2025-21/09/2025  pomeriggio
# 3    DONNARUMMA        228  15/09/2025-21/09/2025  pomeriggio
# 4       TODISCO  CEDRI 251  15/09/2025-21/09/2025     mattina

# %%
# Out:
# datetime.timedelta(seconds=21600)

# %%
from datetime import timedelta


def get_data_inizio(row):
    base_time = datetime.strptime(row['periodo'].split('-')[0], "%d/%m/%Y")
    if row['turno'] == 'mattino':
        return base_time + timedelta(hours=6)
    elif row['turno'] == 'pomeriggio':
        return base_time + timedelta(hours=12)
    elif row['turno'] == 'sera':
        return base_time + timedelta(hours=18)
    else:
        return base_time  # default if turno is missing

df['data_inizio'] = df.apply(get_data_inizio, axis=1)
df['data_fine'] = df['data_inizio']+ timedelta(hours=6)

# %%
df
# Out:
#       collaboratore    reparto                periodo       turno  \
# 0          RIGGIERO        228  15/09/2025-21/09/2025     mattina
# 1          DARIMINI        228  15/09/2025-21/09/2025  pomeriggio
# 2            GIUSTI        228  15/09/2025-21/09/2025  pomeriggio
# 3        DONNARUMMA        228  15/09/2025-21/09/2025  pomeriggio
# 4           TODISCO  CEDRI 251  15/09/2025-21/09/2025     mattina
# ...             ...        ...                    ...         ...
# 2138  SUPPLENTE 30H   DOMENICA             28/06/2026  pomeriggio
# 2139          GRECO   DOMENICA             28/06/2026        sera
# 2140         MONACO   DOMENICA             05/07/2026     mattina
# 2141          NAPPI   DOMENICA             05/07/2026  pomeriggio
# 2142       PASQUINO   DOMENICA             05/07/2026        sera
#
#              data_inizio           data_fine
# 0    2025-09-15 00:00:00 2025-09-15 06:00:00
# 1    2025-09-15 12:00:00 2025-09-15 18:00:00
# ...

# %%
[{"title": str(i[1][0]) + ' - '+str(i[1][1]),"start": str(i[1][4]), "end": str(i[1][5])} for i in df.iterrows()]
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_34304\1640091683.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   [{"title": str(i[1][0]) + ' - '+str(i[1][1]),"start": str(i[1][4]), "end": str(i[1][5])} for i in df.iterrows()]
# [{'title': 'RIGGIERO - 228',
#   'start': '2025-09-15 00:00:00',
#   'end': '2025-09-15 06:00:00'},
#  {'title': 'DARIMINI - 228',
#   'start': '2025-09-15 12:00:00',
#   'end': '2025-09-15 18:00:00'},
#  {'title': 'GIUSTI - 228',
#   'start': '2025-09-15 12:00:00',
#   'end': '2025-09-15 18:00:00'},
#  {'title': 'DONNARUMMA - 228',
#   'start': '2025-09-15 12:00:00',
#   'end': '2025-09-15 18:00:00'},
#  {'title': 'TODISCO - CEDRI 251',
#   'start': '2025-09-15 00:00:00',
#   'end': '2025-09-15 06:00:00'},
#  {'title': 'QUARANTA S - CEDRI 251',
# ...
